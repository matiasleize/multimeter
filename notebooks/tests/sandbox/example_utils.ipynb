# %%
from utils import *  # noqa: F403,F401


def N_sigma_to_L_and_N_eff(N_sigma,Nd):
    PTE = n_sigma_to_PTE(N_sigma)
    L = PTE_to_L(PTE=PTE, Nd=Nd)
    N_eff = L_iso_to_n_eff(d=2, L=L)
    return L, N_eff

# %% [markdown]
# ## DESI DR1 vs DESI DR2

# %%
#DESI DR1 N_Sigma
N_sigma = 1.9
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=2)

print(f'DESI DR1 N_sigma: {N_sigma:.3f}')
print(f'DESI DR1 L: {L:.3f}')
print(f'DESI DR1 N_eff: {N_eff:.3f}')
print('---')

#DESI DR2 N_Sigma
N_sigma = 2.3
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=2)

print(f'DESI DR2 N_sigma: {N_sigma:.3f}')
print(f'DESI DR2 L: {L:.3f}')
print(f'DESI DR2 N_eff: {N_eff:.3f}')
# Out:
# DESI DR1 N_sigma: 1.900
# DESI DR1 L: 2.392
# DESI DR1 N_eff: 1.177
# ---
# DESI DR2 N_sigma: 2.300
# DESI DR2 L: 2.774
# DESI DR2 N_eff: 1.453

# %% [markdown]
# ## Table 1 ($\mathcal{Q}$)

# %%
#Table 1
N_sigma = 1.51
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=3)

print(f'Synthetic case 1 N_sigma: {N_sigma:.3f}')
print(f'Synthetic case 1 L: {L:.3f}')
print(f'Synthetic case 1 N_eff: {N_eff:.3f}')
print('---')


N_sigma = 4.53
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=3)

print(f'Synthetic case 2 N_sigma: {N_sigma:.3f}')
print(f'Synthetic case 2 L: {L:.3f}')
print(f'Synthetic case 2 N_eff: {N_eff:.3f}')
print('---')

N_sigma = 0.429
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=3)

print(f'CC+Planck+BAO N_sigma: {N_sigma:.3f}')
print(f'CC+Planck+BAO L: {L:.3f}')
print(f'CC+Planck+BAO N_eff: {N_eff:.3f}')
print('---')

N_sigma = 1.78
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=3)

print(f'CC+BAO+PPS N_sigma: {N_sigma:.3f}')
print(f'CC+BAO+PPS L: {L:.3f}')
print(f'CC+BAO+PPS N_eff: {N_eff:.3f}')
print('---')

N_sigma = 4.1
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=3)

print(f'Planck+BAO+PPS N_sigma: {N_sigma:.3f}')
print(f'Planck+BAO+PPS L: {L:.3f}')
print(f'Planck+BAO+PPS N_eff: {N_eff:.3f}')
print('---')

N_sigma = 4.33
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=3)

print(f'CC+Planck+PPS N_sigma: {N_sigma:.3f}')
print(f'CC+Planck+PPS L: {L:.3f}')
print(f'CC+Planck+PPS N_eff: {N_eff:.3f}')
# Out:
# Synthetic case 1 N_sigma: 1.510
# Synthetic case 1 L: 1.885
# Synthetic case 1 N_eff: 0.821
# ---
# Synthetic case 2 N_sigma: 4.530
# Synthetic case 2 L: 3.852
# Synthetic case 2 N_eff: 2.250
# ---
# CC+Planck+BAO N_sigma: 0.429
# CC+Planck+BAO L: 1.088
# CC+Planck+BAO N_eff: 0.327
# ---
# CC+BAO+PPS N_sigma: 1.780
# CC+BAO+PPS L: 2.063
# CC+BAO+PPS N_eff: 0.944
# ---
# Planck+BAO+PPS N_sigma: 4.100
# Planck+BAO+PPS L: 3.568
# Planck+BAO+PPS N_eff: 2.039
# ---
# CC+Planck+PPS N_sigma: 4.330
# CC+Planck+PPS L: 3.716
# CC+Planck+PPS N_eff: 2.149

# %% [markdown]
# ## Table 1 ($Q_{DM}$)

# %%
N_sigma = 0.346
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=2)

print(f'CC+Planck N_sigma: {N_sigma:.3f}')
print(f'CC+Planck L: {L:.3f}')
print(f'CC+Planck N_eff: {N_eff:.3f}')
print('---')


N_sigma = 0.189
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=2)

print(f'CC+BAO N_sigma: {N_sigma:.3f}')
print(f'CC+BAO L: {L:.3f}')
print(f'CC+BAO N_eff: {N_eff:.3f}')
print('---')

N_sigma = 2.57
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=2)

print(f'CC+PPS N_sigma: {N_sigma:.3f}')
print(f'CC+PPS L: {L:.3f}')
print(f'CC+PPS N_eff: {N_eff:.3f}')
print('---')

N_sigma = 5.68
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=2)

print(f'Planck+PPS N_sigma: {N_sigma:.3f}')
print(f'Planck+PPS L: {L:.3f}')
print(f'Planck+PPS N_eff: {N_eff:.3f}')
print('---')

N_sigma = 1.39
L, N_eff = N_sigma_to_L_and_N_eff(N_sigma, Nd=2)

print(f'BAO+PPS N_sigma: {N_sigma:.3f}')
print(f'BAO+PPS L: {L:.3f}')
print(f'BAO+PPS N_eff: {N_eff:.3f}')
# Out:
# CC+Planck N_sigma: 0.346
# CC+Planck L: 0.794
# CC+Planck N_eff: 0.185
# ---
# CC+BAO N_sigma: 0.189
# CC+BAO L: 0.570
# CC+BAO N_eff: 0.100
# ---
# CC+PPS N_sigma: 2.570
# CC+PPS L: 3.032
# CC+PPS N_eff: 1.642
# ---
# Planck+PPS N_sigma: 5.680
# Planck+PPS L: 6.025
# Planck+PPS N_eff: 3.858
# ---
# BAO+PPS N_sigma: 1.390
# BAO+PPS L: 1.901
# BAO+PPS N_eff: 0.833
